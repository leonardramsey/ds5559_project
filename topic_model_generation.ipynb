# %% [markdown]
# # Configuration

# %%
db_file_names = [
                 'db/2701-0.db',
#                  'db/a_tale_of_two_cities.db',
#                  'db/anna_karenina.db',
                 'db/captains_courageous.db',
#                  'db/emma.db',
                 'db/far_from_madding_crowd.db',
                 'db/heart_of_darkness.db',
                 'db/jane_eyre.db',
#                  'db/pride_and_prejudice.db'
                 ]
max_words = 10000

# For MALLET
num_topics = 20
num_iters = 1000
show_interval = 100
mallet_path = '/Users/leonardramsey/Downloads/mallet-2.0.8/bin/mallet'

# %% [markdown]
# #  Libraries

# %%
import pandas as pd
import sqlite3, os
import textman as tx

# %% [markdown]
# # Process

# %% [markdown]
# ## Import novel corpus from database
#
# We use SQL to get what we want quickly.

# %%
sql = """
SELECT * FROM token 
WHERE term_id IN (
    SELECT term_id FROM vocab 
    WHERE stop = 0 
    AND term_str NOT IN ('said')
    ORDER BY tfidf_sum DESC LIMIT {}
)
-- AND (pos NOT LIKE 'NNP%')
""".format(max_words)

# %%
tokens_list = []

for db_file_index in range(0, len(db_file_names)): 
    with sqlite3.connect(db_file_names[db_file_index]) as db:
        tokens_list.append(pd.read_sql(sql, db))
        # fix tokens dataframe
        tokens_list[db_file_index] = tokens_list[db_file_index].set_index(['chap_num','para_num','sent_num'])
        print(tokens_list[db_file_index].head())
        print(len(tokens_list[db_file_index].term_str.unique()))
# Out:
#                             token_num  pos token_str  punc  num  term_str  \
# chap_num para_num sent_num
# 0        1        0                 1  VBN  Supplied     0    0  supplied
#                   0                 4   JJ      Late     0    0      late
#                   0                10  NNP    School     0    0    school
#          2        0                 1   NN      pale     0    0      pale
#                   0                 6   NN      coat     0    0      coat
#
#                             term_id
# chap_num para_num sent_num
# 0        1        0           14441
#                   0            8383
#                   0           12718
#          2        0           10359
#                   0            2686
# 10000
#                             token_num pos token_str  punc  num term_str  \
# chap_num para_num sent_num
# 0        0        0                 0  NN   CHAPTER     0    0  chapter
#          1        0                 1  NN   weather     0    0  weather
#                   0                 2  NN      door     0    0     door
#                   0                 5  NN   smoking     0    0  smoking
#                   0                 7  NN      room     0    0     room
#
#                             term_id
# chap_num para_num sent_num
# 0        0        0            1030
#          1        0            6460
#                   0            1698
#                   0            5339
#                   0            4825
# 6592
#                             token_num  pos   token_str  punc  num    term_str  \
# chap_num para_num sent_num
# 0        0        0                 0   NN     PREFACE     0    0     preface
#          1        0                 1  VBG  reprinting     0    0  reprinting
#                   0                 3   NN       story     0    0       story
#                   0                 6   JJ         new     0    0         new
#                   0                 7   NN     edition     0    0     edition
#
#                             term_id
# chap_num para_num sent_num
# 0        0        0            7485
#          1        0            8138
#                   0            9454
#                   0            6535
#                   0            3031
# 10000
#                             token_num  pos token_str  punc  num  term_str  \
# chap_num para_num sent_num
# 0        0        0                 0   NN   CHAPTER     0    0   chapter
#          1        0                 1  NNP    Nellie     0    0    nellie
#                   0                 4   NN  cruising     0    0  cruising
#                   0                 5   NN      yawl     0    0      yawl
#                   0                 7   NN     swung     0    0     swung
#
#                             term_id
# chap_num para_num sent_num
# 0        0        0             859
#          1        0            3269
#                   0            1182
#                   0            5514
#                   0            4820
# 5412
#                             token_num  pos token_str  punc  num term_str  \
# chap_num para_num sent_num
# 0        0        0                 0   NN   PREFACE     0    0  preface
#          1        0                 1   NN   preface     0    0  preface
#                   0                 4   JJ     first     0    0    first
#                   0                 5   NN   edition     0    0  edition
#                   0                 8  NNP      Jane     0    0     jane
#
#                             term_id
# chap_num para_num sent_num
# 0        0        0            8423
#          1        0            8423
#                   0            4424
#                   0            3613
#                   0            6190
# 10000

# %% [markdown]
# ## Convert tokens to a corpus for MALLET input

# %%
corpora = {}
for tokens_index in range(0, len(tokens_list)):
    corpus = tx.gather_tokens(tokens_list[tokens_index], level=2, col='term_str')\
        .reset_index().rename(columns={'term_str':'doc_content'})
    corpus['doc_label'] = corpus.apply(lambda x: "doyle-{}-{}".format(x.chap_num, x.para_num), 1)
    corpora[db_file_names[tokens_index]] = corpus
    corpus.head()

# %% [markdown]
# ## Dump corpus to CSV file

# %%
for name in corpora:
    corpus = corpora[name]
    name = name.replace('db', '')
    name = name.replace('/', '')
    name = name.replace('.', '')
    if not os.path.exists('topic_models/%s/' % name):
        os.makedirs('topic_models/%s/' % name)
    corpus[['doc_label','doc_content']].to_csv('topic_models/%s/%s.csv' % (name, name), index=False)

# %% [markdown]
# ## MALLET Time

# %% [markdown]
# ### Show MALLET options

# %%
# !{mallet_path}
# Out:
# Unrecognized command:
# Mallet 2.0 commands:
#
#   import-dir         load the contents of a directory into mallet instances (one per file)
#   import-file        load a single file into mallet instances (one per line)
#   import-svmlight    load SVMLight format data files into Mallet instances
#   info               get information about Mallet instances
#   train-classifier   train a classifier from Mallet data files
#   classify-dir       classify data from a single file with a saved classifier
#   classify-file      classify the contents of a directory with a saved classifier
#   classify-svmlight  classify data from a single file in SVMLight format
#   train-topics       train a topic model from Mallet data files
#   infer-topics       use a trained topic model to infer topics for new documents
#   evaluate-topics    estimate the probability of new documents under a trained model
#   prune              remove features based on frequency or information gain
#   split              divide data into testing, training, and validation portions
#   bulk-load          for big input files, efficiently prune vocabulary and import docs
#
# Include --help with any option for more information

# %% [markdown]
# ### Import Each Corpus and Train

# %%
for name in corpora:
#     print(corpora)
    name = name.replace('db', '')
    name = name.replace('/', '')
    name = name.replace('.', '')
    
    # !{mallet_path} import-file --input topic_models/{name}/{name}.csv --output topic_models/{name}/{name}.mallet --keep-sequence TRUE

    # !{mallet_path} train-topics --input topic_models/{name}/{name}.mallet --num-topics {num_topics} --num-iterations {num_iters} \
    --output-doc-topics topic_models/{name}/{name}-doc-topics.txt \
    --output-topic-keys topic_models/{name}/{name}-topic-keys.txt \
    --word-topic-counts-file topic_models/{name}/{name}-word-topic-counts-file.txt \
    --topic-word-weights-file topic_models/{name}/{name}-topic-word-weights-file.txt \
    --xml-topic-report topic_models/{name}/{name}-topic-report.xml \
    --xml-topic-phrase-report topic_models/{name}/{name}-topic-phrase-report.xml \
    --show-topics-interval {show_interval} \
    --use-symmetric-alpha false  \
    --optimize-interval 100 \
    --diagnostics-file topic_models/{name}/{name}-diagnostics.xml
# Out:
# Mallet LDA: 20 topics, 5 topic bits, 11111 topic mask
# Data loaded.
# max tokens: 214
# total tokens: 82537
# <10> LL/token: -9.72984
# <20> LL/token: -9.52283
# <30> LL/token: -9.41015
# <40> LL/token: -9.36445
# <50> LL/token: -9.31683
# <60> LL/token: -9.28477
# <70> LL/token: -9.2554
# <80> LL/token: -9.24234
# <90> LL/token: -9.23027
#
# 0	0.25	ahab thou whale thee starbuck men white still look thy old must dick moby cried eye god shall see man
# 1	0.25	whale one sea like tail sort story lord seems curious deep living power plainly times know jet still though saw
# 2	0.25	ship boat pequod boats captain time stubb crew ahab board side vessel way wind came soon near thought cried moment
# 3	0.25	would night day never man round harpooneer first could hard upon something life mind one always bed world made sharks
# 4	0.25	much must though great may man think might last would men well like many even aye time heart live also
# 5	0.25	deck man ahab mast old heads upon cabin head mate captain eyes ship something main watch crew quarter heard aloft
# 6	0.25	one feet three long voyage years far last ever four made whale gone length fine hundred men five first ten
# 7	0.25	like sea white round air head high along bottom line sight black red ship great full sudden tossed open sails
# 8	0.25	ever water sea like sort without yet air sometimes heard blood earth thing look therefore death high living came seems
# 9	0.25	queequeg stubb little sir flask hand like head soon away light coffin room see skin going hat bed coat water
# 10	0.25	seemed upon still yet eyes though never face almost see brow last indeed would rolling green strange rest passed thought
# 11	0.25	every could seemed thing may however seen strange whales soul open yet rather pip tell far hope must seem land
# 12	0.25	whale sperm whales one great right fish found head fishery body dead among large say seem whalemen greenland account known
# 13	0.25	upon sea ships seas waters new long nantucket ocean among many whose sun days ground vast first name pacific world
# 14	0.25	one side hand two end line long back every harpoon rope boat leg iron lance upon take starbuck kept cutting
# 15	0.25	one good captain make know say bildad right little poor better peleg thing young way left would devil away might
# 16	0.25	like whale ship upon round boat water towards half last head three jaw part deck along beneath saw hole standing
# 17	0.25	whale old oil full great hands part king sea try may say much leviathan book skeleton day case time two
# 18	0.25	man would things though world even come whaling business home many perhaps way hold plain view often otherwise people among
# 19	0.25	fish old two time way without top fast might little queequeg found take get sail head point stand called sailors
#
# <100> LL/token: -9.20547
# <110> LL/token: -9.19558
# <120> LL/token: -9.18633
# <130> LL/token: -9.1872
# <140> LL/token: -9.17491
# <150> LL/token: -9.16361
# <160> LL/token: -9.14209
# <170> LL/token: -9.14569
# <180> LL/token: -9.14109
# <190> LL/token: -9.12923
#
# 0	0.25	thou man ahab thee white starbuck whale thy dick must moby shall look still men ever old fire aye cried
# 1	0.25	whale sea much jonah one land story blood water living power times tail body savage might though lord monster deep
# 2	0.25	ship boat pequod boats stubb ahab captain crew time board vessel harpooneers cried mate chase soon first near three two
# 3	0.25	would day never night could one thought man see sort whether harpooneer hard half made bed seen think sleep something
# 4	0.25	great man much time must though many like may life called men indeed dead comes old yet live also would
# 5	0.25	deck ahab mast heads head cabin upon crew captain one heard ship old main last sail almost stood night man
# 15	0.27945	captain good ship say way come never let would know bildad get peleg well sir board hands better round cried
# 16	0.2625	whale head upon like side body part tail back jaw mouth spout lower water surface high vast sperm broad great
# 17	0.17907	oil ship keep try many hold works work going full called low best casks live far mariners pots pieces dat
# 18	0.23705	yet though things man life one whole even world strange still times whaling men never least death matter soul often
# 19	0.21374	old stubb little queequeg small time boy queer often king young legs might fellow says came round alone wise fine
#
# [beta: 0.0346]
# <600> LL/token: -9.25692
# <610> LL/token: -9.25427
# <620> LL/token: -9.2598
# <630> LL/token: -9.25426
# <640> LL/token: -9.26608
# <650> LL/token: -9.25373
# <660> LL/token: -9.25677
# <670> LL/token: -9.26025
# <680> LL/token: -9.2482
# <690> LL/token: -9.26104
#
# 0	0.21432	man thou ahab thee thy dick moby ever old last made starbuck aye shall heart yet dead must fire enough
# 1	0.19544	whale white great jonah even upon sea god story like though noble lord name land deep leviathan ancient soul gone
# 2	0.28904	boat ship boats whale ahab crew stubb upon starbuck round time pequod one near every men cried two still three
# 3	0.25772	would one day see night time could come man ever long hard morning half thought first harpooneer put tell till
# 4	0.23223	must one time though little may much whaling first voyage thought way case indeed chance however yet thing still certain
# 5	0.24853	deck mast head hand upon side heads one sea every standing old like three two came main man till aloft
# 6	0.18981	one feet two three years length whales long four hundred five ten part days twenty large thousand miles fifty men
# 7	0.26037	like sea white air round water seemed away sun half blue sharks deep still almost waters along waves rolled tossed
# 8	0.18518	like world must earth old man among upon live comes heaven living seems sun head yet beneath every woe looks
# 9	0.22966	queequeg little upon room bed light door open took coffin pipe one poor enough went soon table short set back
# 10	0.23099	ahab eyes seemed without face towards like last stood still seen saw cabin men crew eye within heard starbuck wild
# 11	0.2083	might thing though would could much sort whether strange seemed always whatever since business almost keep indeed way peculiar find
# 12	0.26236	whale whales sperm one fish great right found known fishery may among leviathan called english present yet almost greenland often
# 13	0.21179	sea ship ships nantucket upon many new seas ocean long indian ground whaling wild last voyage may home far sail
# 14	0.23795	one line boat end long iron hand way harpoon fish fast round two whale hold rope lance first straight cutting
# 15	0.28354	captain ship good say never well get bildad give old make peleg let would leg pequod board better look way
# 16	0.25255	whale head like great part upon tail water body sperm jaw spout broad lower side vast bone surface high mouth
# 17	0.15602	oil try hold full sometimes small works work called casks pots keep business pieces dat shark dam much mariners ship
# 18	0.22943	life yet things though man world whole seemed death even could times never still men whose far matter one without
# 19	0.20115	old stubb little flask boy time sir fine king good queer cook says nothing hand fellow away something pip young
#
# [beta: 0.03489]
# <700> LL/token: -9.25065
# <710> LL/token: -9.25154
# <720> LL/token: -9.24945
# <730> LL/token: -9.25619
# <740> LL/token: -9.24615
# <750> LL/token: -9.2526
# <760> LL/token: -9.24594
# <770> LL/token: -9.25247
# <780> LL/token: -9.25357
# <790> LL/token: -9.24202
#
# 0	0.20379	thou man ahab thee must thy dick moby old made aye let men shall fire last dead god ever starbuck
# 1	0.17902	whale great white sea jonah even upon lord gone story god noble monster land times shall golden kings mad stand
# 13	0.19295	ships long sea upon ship nantucket seas many far new voyage whaling last world ground ocean sail indian waters whose
# 14	0.21792	one line fish long end whale hand iron fast like way harpoon boat rope first arm hold away two round
# 15	0.28778	captain ship good man come sir would ahab say old never stubb bildad peleg starbuck cried give know let way
# 16	0.23189	whale head like part sperm tail great body side jaw spout water white lower bone mouth surface vast much high
# 17	0.12006	oil try hold works live casks good dat blubber dam work shark pots carries get spermaceti state lamp rare leak
# 18	0.20776	yet one life though things even still man soul death men full times form mere seemed never whole power far
# 19	0.17688	old stubb man flask look pip boy little poor young fellow cook know says time king queer one wise boys
#
# [beta: 0.03494]
# <900> LL/token: -9.2301
# <910> LL/token: -9.23632
# <920> LL/token: -9.22941
# <930> LL/token: -9.23074
# <940> LL/token: -9.24115
# <950> LL/token: -9.23655
# <960> LL/token: -9.23689
# <970> LL/token: -9.23966
# <980> LL/token: -9.23909
# <990> LL/token: -9.22645
#
# 0	0.18214	thou ahab thee thy dick must moby man aye ever shall dead last made enough eye old fear mine still
# 1	0.14522	great whale jonah white god even old lord times king sea story land find gone royal shall alone idea holy
# 2	0.29317	boat whale ship boats stubb one pequod time crew round ahab upon two soon three still sea every water starbuck
# 3	0.24328	would one see night day never time hard nothing thought yet upon must man mind could half small found matter
# 4	0.23131	though must may much upon still perhaps case time many whaling business things thing certain say way little voyage general
# 5	0.22505	deck head mast hand man heads one like upon every top sail look till old main came aloft two tashtego
# 6	0.14965	feet one three years two four length hundred whales long upon five full ten twenty hours fifty lay six large
# 7	0.23621	sea like air white water seemed round sharks deep upon blue away half wake still blood seas rolling waters behind
# 8	0.14722	like world old sun heaven living beneath among earth heart upon way gold seems comes beat fancy awful whole read
# 9	0.19805	queequeg little room door bed back like open one pipe without table coffin arm light looking something soon first upon
# 10	0.21532	ahab eyes face stood upon still saw yet seemed last looked night ship starbuck half men eye remained cabin deck
# 11	0.19974	could might thing would every though almost seemed way last sort times whether indeed since well whatever least ever strange
# 12	0.23904	whale whales sperm one great fish found right fishery leviathan often known first sometimes among called may whalemen english whaleman
# 13	0.18904	sea ships nantucket new whaling many ship long ocean seas ground upon world waters indian men far pacific voyage sailing
# 14	0.21102	line long one hand fish end harpoon iron fast boat whale two rope hold round cutting hands away broken lance
# 15	0.29271	captain man ship would good old say come ahab sir one cried bildad let starbuck peleg word see know never
# 16	0.22116	whale head like sperm side part tail great body jaw bone surface upon lower water mouth spout broad beneath high
# 17	0.10803	oil try hold works good sea called thing casks fight done pots dat blubber lamp rare ship carry state dry
# 18	0.19577	life one man yet even things though death seen soul far still made world noble feel may power long men
# 19	0.16579	stubb old little poor time pip flask fellow boy look queer cook sort know young away father wife king wise
#
# [beta: 0.03558]
# <1000> LL/token: -9.22823
#
# Total time: 12 seconds
# Mallet LDA: 20 topics, 5 topic bits, 11111 topic mask
# Data loaded.
# max tokens: 81
# total tokens: 21446
# <10> LL/token: -9.78649
# <20> LL/token: -9.64987
# <30> LL/token: -9.58142
# <40> LL/token: -9.5505
# <50> LL/token: -9.52379
# <60> LL/token: -9.49886
# <70> LL/token: -9.4908
# <80> LL/token: -9.46383
# <90> LL/token: -9.47574
#
# 0	0.25	fish anchor man sea dead deck cod boat around virgin foot knife stood pen among always fog berth later heads
# 1	0.25	harvey dory dan eye one went something bottom water alongside manuel called tackle deck stern nothing carrie slipped hook caught
# 2	0.25	say jest wet could salt good even never like piece naow goin git find anything mind edge silence nose baout
# 3	0.25	right see harvey gloucester fleet kind across says many mile yet world point think cod asked seemed body first looking
# 4	0.25	time back two hand business hundred away thousand year thirty life everything men lay six car felt san women town
# 5	0.25	cheyne run mrs put told father city weather found street single way lost constance tale talk folk ag'in hands name
# 6	0.25	one day made boats another see clear every cried great mother looked away spoke life except french crews best schooners
# 7	0.25	like little voice heard harvey ran high overboard set small jedgments deep square aboard johnstown hove tiny fall black breath
# 8	0.25	would half back fish one luck east came head ten made stay hatch west going less followed island wind breakfast
# 9	0.25	boat white head blue full days water red one time air face side hands summer along house light boots hung
# 10	0.25	salters penn till uncle work catch water replied cut men light kinder upon face fell night mad nothin yacht kept
# 11	0.25	boy could man schooner disko watch crew took last rest thought turned dories lay side along skipper banks till think
# 12	0.25	old three two five four dollars never money years month got man last every ohio forty times twenty boston horn
# 13	0.25	n't fer take dad new good better tell give know enough guess york ha'af course sure want abaout sez let
# 14	0.25	sea ever look troop son night lead time second place man aboard day fishing stand one else since full bunk
# 15	0.25	long platt tom jack line disko manuel round till lines short went filled talk thing stick sleep master ere trawl
# 16	0.25	dan harvey eyes end sat rope round without table hand forward first though even shouted story fast blood show fried
# 17	0.25	men began wheel like head long boom shot hour sail others jib cable call dropped quite windlass silent called crowd
# 18	0.25	disko little fog young cook behind boys make cabin c'sle feller things home came big thick main took aft rather
# 19	0.25	n't way harve come man much fer get things done hev dan though heap anything thet fore along say aout
#
# <100> LL/token: -9.44316
# <110> LL/token: -9.43467
# <120> LL/token: -9.44055
# <130> LL/token: -9.42914
# <140> LL/token: -9.41931
# <150> LL/token: -9.42968
# <160> LL/token: -9.42661
# <170> LL/token: -9.42381
# <180> LL/token: -9.40874
# <190> LL/token: -9.42478
#
# 0	0.25	fish man boat dead among sea salt cod bait hold anchor knife open later stood pen edge anything deep always
# 1	0.25	harvey dory dan deck one lay bottom cod alongside water manuel big tackle replied caught found virgin called fish hook
# 2	0.25	say troop man disko well jest right every piece good business come summer goin war aboard put baout keep git
# 3	0.25	see like think thing kind says fleet tell take seemed harvey looking world point yet going asked right mad get
# 4	0.25	two back went hundred men boat time hand thousand year thirty look six car foot every board banks used san
# 5	0.25	cheyne new time told father mrs gloucester line city last run street single stay constance folk boston ag'in tale name
# 6	0.25	one men day another clear life next seen crowd make mother except hold best french iron made crews coast women
# 7	0.25	little away back harvey voice round high never ran great like around heard far boston craft fall silver lee hove
# 8	0.25	would half made way main back east hatch mile gave sea something carrie ten stand came followed island pitman might
# 9	0.25	head water face full blue red along white across berth air week boots hung eyes bank held jersey top hard
# 10	0.25	salters penn though till uncle dan disko catch things luck ashore naow called cut set bad sez upon aboard slipped
# 11	0.25	could boy side took schooner along skipper watch first rest help turned let find asleep thought made together decks knew
# 12	0.25	old man three days five four years got first twenty last dollars month trip two forty ohio never horn fifteen
# 13	0.25	n't fer dad know give take money guess good dan course ha'af enough want sure abaout blame better struck wanted
# 14	0.25	sea night dories boats ever black time cried day son lead eye woman fishing place sails since everything sort fleet
# 15	0.25	long platt jack tom disko till work manuel trawl must like bunk talk filled anyway round stick line went ere
# 16	0.25	harvey dan end eyes hand weather one sat rope fast without spoke hands table blood even forward story pipe breath
# 17	0.25	like light dropped began anchor others cable looked wind hour boom shot wheel sail quite hot wet jib within windlass
# 18	0.25	fog little young cook behind cabin came c'sle heart feller home boys bell disko sight big kinder breakfast ended hurry
# 19	0.25	n't way harve much fer hev done fore make come even better heap never thet araound things jedgments ireson share
#
# <200> LL/token: -9.40247
# <210> LL/token: -9.41229
# <220> LL/token: -9.3898
# <230> LL/token: -9.40324
# <240> LL/token: -9.40436
# <250> LL/token: -9.41147
# <260> LL/token: -9.38536
# <270> LL/token: -9.38879
# <280> LL/token: -9.39934
# <290> LL/token: -9.37728
#
# 0	0.25	fish man dead cod anchor among bait hold salt knife fell hand anything later work still deck two opened stood
# 1	0.25	dory harvey one lay big line fish found bottom water fog deck manuel alongside tackle caught eye schooner virgin something
# 2	0.25	man say right old troop good well jest aboard come son piece disko boy work goin else baout gloucester got
# 3	0.25	see think dan tell get men kind clear mother take thing struck held ear world point words says going strike
# 4	0.25	back time every two till thousand went year business foot six like hundred car board san crew sails forth miles
# 5	0.25	cheyne new father told york know mrs city time might must street lost constance boston name chicago use nothing tale
# 6	0.25	one day men never boat life till next seen many crowd crews story best women almost ashore call pride except
# 7	0.25	harvey away little like boat around ran round voice high wharf deep overboard sea set boots small heard let square
# 8	0.25	would half way back made east hatch mile even wind short stand carrie rest came followed everything season island lee
# 9	0.25	head water face blue white red hand air across bank full house seemed went berth grey silence jersey cut sleep
# 10	0.25	salters penn dan uncle things catch keep cried sure put naow sez bad till though luck talk johnstown main remember
# 11	0.25	could boy along together watch skipper banks took schooner thought first called summer find side gave hands cheyne heard people
# 12	0.25	three days old five four two dollars ten years month thirty time made forty ohio twenty hundred week horn iron
# 13	0.25	n't fer dad take give enough ha'af good know guess money want abaout course blame git kinder miss nothin let
# 14	0.25	sea last night ever boats dories black fleet side full lead round fishing gone mad like may came line sort
# 15	0.25	long platt tom jack disko though manuel without dory bunk anyway till filled cut trawl stick pipe replied eye rowed
# 16	0.25	dan harvey eyes end sat forward hands look one fast far took felt looking table rope feet went blood help
# 17	0.25	like little light began wet looked others water boom shot woman hot jib anchor sail windlass shouted dry dropped deck
# 18	0.25	young cook boys great harvey disko fog behind c'sle cabin wheel feller second sight bell came first asked aft thick
# 19	0.25	n't much way harve better make hev done come heap yet thet fore araound though war stay anything run jedgments
#
# [beta: 0.02989]
# <300> LL/token: -9.27946
# <310> LL/token: -9.49521
# <320> LL/token: -9.55037
# <330> LL/token: -9.52872
# <340> LL/token: -9.52412
# <350> LL/token: -9.51564
# <360> LL/token: -9.52333
# <370> LL/token: -9.51149
# <380> LL/token: -9.52937
# <390> LL/token: -9.53599
#
# 0	0.24838	fish cod dead water cook sea heard salt hold away harvey berth air like wet knife call man deep troop
# 1	0.2619	dan dory harvey fish boat lay bottom deck one line manuel till tackle around hook alongside caught mile lines full
# 2	0.26191	man old right ever good son work say jest got well baout brought horn aboard run lord daown yet kind
# 3	0.24529	see think things home come get say must weather clear tell take quite blood ear back says town packet world
# 4	0.2361	time every went hand two one year away back six board forth car business asked like read slid hour private
# 5	0.24309	cheyne new york mrs know city boston street lost single chicago name since french taken last noo san albany married
# 6	0.25961	one never men time life father day thing little another though next seen mother many piece told better even stay
# 7	0.24472	way like half little wharf boat overboard dan water set skipper small rose clean foot big upon eye bank craft
# 8	0.24815	would back half anchor seemed made something carrie followed wanted pitman haul rest within found island east play ready might
# 9	0.24323	head face blue white red others full open across house water jersey high morning top boots flat cut oilskins green
# 10	0.24037	salters penn uncle dan till catch voice main keep cried things along johnstown slipped hatch boys cut naow sez sep'rate
# 11	0.25555	could boy disko took made schooner along even make called gave thought summer used short together coast business work school
# 12	0.24483	three two five hundred dollars four years days ten month thirty twenty day forty gloucester thousand miles quintal fifteen minutes
# 13	0.27218	n't fer dad good give take money enough guess ha'af course trip want let sure blame abaout know bait tell
# 14	0.23586	sea like side night dories boats round fleet black last looked men fishing came virgin woman bank grey swung light
# 15	0.23842	long platt tom jack disko till manuel replied among round put tune lead ere forward nose though know went hauled
# 16	0.26171	harvey dan eyes end hands one sat look rope table forward talk show fast pipe fried stove feet stung line
# 17	0.2303	little began dropped wheel light water boom like shot anchor sail jib held cabin windlass wet pen dry c'sle aft
# 18	0.24283	harvey fog first young great behind watch disko without came feller ran bell head hand sight thick second heart stood
# 19	0.27388	n't fer harve much way hev make done come anything heap fore war thet troop araound though else jedgments aboard
#
# [beta: 0.03842]
# <400> LL/token: -9.51133
# <410> LL/token: -9.57258
# <420> LL/token: -9.56333
# <430> LL/token: -9.58499
# <440> LL/token: -9.55409
# <450> LL/token: -9.55839
# <460> LL/token: -9.56315
# <470> LL/token: -9.60067
# <480> LL/token: -9.56533
# <490> LL/token: -9.57194
#
# 0	0.23785	fish cod water wet salt little began another dropped boat air bait piece fresh pen hold edge deck held knife
# 1	0.2651	harvey dory dan line manuel lay full bottom deck rope tackle sea found nothing boat hook caught rather know fog
# 2	0.26371	man old well work say ever dead think good son fleet anyway baout later best boys next crew boy says
# 3	0.2383	see hand back till light think must clear quite struck west cook ear boston rowed skipper sez take counahan bunk
# 4	0.22982	time away every day back kind hour went asked board square forth worth dead book half big chorus sence hung
# 5	0.2177	cheyne new york mrs city let car last street san boston chicago run know packet hurry constance private time single
# 6	0.25886	one men never till though life boat told father even seen many ashore week took better stay people another days
# 7	0.22628	dan like voice talk wharf far look eye small high heard body bank watch heap heres whale eyes frenchman light
# 8	0.23154	would half made wind anchor still round east went gloucester day called carrie pitman island within see place might making
# 9	0.22115	head white water blue side harvey face across back sea red boots open full looked jersey morning cut grey rose
# 10	0.23598	salters penn uncle things little put keep time like naow johnstown cook mad could sep'rate folks hove replied poor face
# 11	0.24858	disko could boy along make schooner made called business summer course short world gave used others stick words even sort
# 12	0.23476	two three hundred five one dollars four ten thousand month days years forty twenty year six times thirty quarter fifteen
# 13	0.29025	fer n't dad good take give guess catch say luck better enough get abaout trip troop sure want bad money
# 14	0.22301	like sea night dories boats men ran round fishing sails fleet gloucester came breath looked black aboard heard swell schooners
# 15	0.23433	long platt tom jack disko forward went round lead tune manuel among replied trawl ere troop hatch neck deep boats
# 16	0.2547	harvey end dan eyes hands one something table sat mother feet show saw stove kept supper fried weather found threw
# 17	0.21265	little c'sle anchor shot big wheel boom boys sail together jib cable water ship aft along rolled windlass riding ladder
# 18	0.23947	first fog behind young dan head came cabin harvey main banks feller great sight second around fish cried foot crew
# 19	0.29114	n't way harve right come much hev fore tell anything jest home done araound thet else aboard aout ag'in got
#
# [beta: 0.04207]
# <500> LL/token: -9.5616
# <510> LL/token: -9.59891
# <520> LL/token: -9.57556
# <530> LL/token: -9.60932
# <540> LL/token: -9.59424
# <550> LL/token: -9.57828
# <560> LL/token: -9.57775
# <570> LL/token: -9.57162
# <580> LL/token: -9.59378
# <590> LL/token: -9.5764
#
# 0	0.22279	fish water little cod began wet deep big salt pen anyway knife like filled among heres away moved dry edge
# 1	0.26343	harvey dory boat dan end manuel line lay bottom schooner rope without fog dropped alongside sea fast full wharf hook
# 2	0.26811	man old boy dead anything ever n't make next crowd work everything thing got lord ohio haul war name better
# 3	0.22899	see back think come light clear full men struck fresh till sea first sez weather wid must counahan jest hurt
# 4	0.21193	went time hand every back along get place berth board another bank forth hour supper two skipper hair green second
# 5	0.19782	cheyne new york mrs city street boston san constance chicago car run kinzey single might miss married noo know albany
# 6	0.26413	one day never would time made till told father men life seen take ashore thought took son harvey women town
# 7	0.20637	dan harvey like look high cried heard face yet hove slipped forward ended voice one overside far fog stuck salt
# 8	0.21497	would half anchor round cable away east sea virgin still carrie tackle went followed mile seemed lay lead pitman island
# 9	0.206	blue white water together back red across right behind grey looked face house sat silver room cut silence boots jersey
# 10	0.22359	salters penn uncle little night like cook keep bad things put fish johnstown boys crew luck tune disko sep'rate breath
# 11	0.24188	could disko things kind along others men talk even summer heard boy world called used coast business horn best gave
# 12	0.22216	two three five four dollars hundred half ten days thousand thirty year years old six twenty forty month miles fifteen
# 13	0.319	n't fer say dad give good take much dan enough right catch better done home ha'af make course want says
# 14	0.20521	like sea fleet boats gloucester man men sails fishing woman dories say ice cut cold beyond night bank ride coal
# 15	0.21572	long platt tom jack disko though till forward round use manuel replied saw put must fiddle accordion galway locker lee
# 16	0.24321	harvey one eyes side hands eye head black hand table feet sat mother except set tiny cook cheyne bunk something
# 17	0.19229	c'sle came deck wheel boom jib main windlass wind hatch fried asleep shot stood cabin stern fog clean dark fish
# 18	0.23816	young last head man first around great ran feller watch bell brought top behind one french knew hauled later pennsylvania
# 19	0.30774	n't way harve dan tell fore hev see aboard let piece disko till troop naow thet come stay crazy jedgments
#
# [beta: 0.04307]
# <600> LL/token: -9.58413
# <610> LL/token: -9.57895
# <620> LL/token: -9.58272
# <630> LL/token: -9.57293
# <640> LL/token: -9.59655
# <650> LL/token: -9.57542
# <660> LL/token: -9.57184
# <670> LL/token: -9.59213
# <680> LL/token: -9.57262
# <690> LL/token: -9.57368
#
# 0	0.21107	like fish water cod dropped wet began salt among men big knife wharf deep pen heads slid little silver heres
# 1	0.26715	harvey dory dan till one schooner boat lay side manuel deck along end fog sea rope without line big bottom
# 2	0.27621	man old boy make dead ever son thing got great alongside two lord hurry face fit find went tune packet
# 3	0.21855	back till boat full aboard struck light clear felt spoke brought upon night town come skipper strike french coast filled
# 4	0.1939	see half time another second hour berth back cheyne sight hand room held bank could forth wid cape state gave
# 5	0.1795	cheyne new york mrs know every street car constance chicago city single main boston kinzey miss private time hours white
# 6	0.26519	one would never day time could made father life things might ashore took mother every better except stay story people
# 7	0.20458	dan harvey though voice cried went back look far must use home married yacht supper high forward ear thick hall
# 8	0.19661	wind still virgin would anchor half tackle line carrie round mile east pitman found island word shoals near looking whistling
# 9	0.18987	water blue red looked white behind across made air black nose hard face jersey boots iron together cut sort cap
# 10	0.20463	salters little penn uncle boys weather asked bad name told johnstown pennsylvania remember public poor coffee catch araound stand rich
# 11	0.23137	disko could even called kind things boy along keep fleet world summer stick ready short took boarders turned end others
# 12	0.20877	two three five hundred four dollars days away years ten thousand thirty year twenty day month money forty six miles
# 13	0.34822	n't fer good take say dad right dan done jest enough give work ha'af see come fish heap want luck
# 14	0.18841	like sea men night came woman fishing dories black boats fleet silent gloucester bank round women seas breath gone ended
# 15	0.20665	long platt jack tom disko put manuel round forward though went lead replied seen hatch stern stuck neck galway boats
# 16	0.23945	harvey head eyes hand one eye ran sat cabin table cook sea set show hands feet rather hung little pipe
# 17	0.17415	c'sle wheel hot sail cook together deck jib windlass cut anchor clean bows ship ladder fried rail came others within
# 18	0.22172	last man young banks around feller trip crowd first help boats behind quarter harvey matter hotel open bait laughed youth
# 19	0.31161	n't way harve think much tell dan anything know piece next hev fore run talk let thet guess jedgments else
#
# [beta: 0.04404]
# <700> LL/token: -9.57011
# <710> LL/token: -9.57012
# <720> LL/token: -9.5488
# <730> LL/token: -9.55634
# <740> LL/token: -9.56499
# <750> LL/token: -9.55158
# <760> LL/token: -9.56432
# <770> LL/token: -9.58587
# <780> LL/token: -9.55268
# <790> LL/token: -9.55091
#
# 0	0.20452	like fish water cod wet began dropped salt knife berth board pen deep upon heads edge dory bank tub known
# 1	0.27652	harvey dory water side another along manuel line bottom deck rope end schooner dan boat air feet sea fell lines
# 14	0.2606	room fire stood table side sat chair round near took two looking window bed hands back little head candle placed
# 15	0.22271	every made last night rochester gave seemed till appeared deep take glance put word days liberty words away point rather
# 16	0.21852	jane thing pleasure think good rather wish affection sense state got feelings love real amongst eyre added thus want bad
# 17	0.23117	good much though woman nothing feel heart man well never presence less sure hard somewhat handsome truth eye smile little
# 18	0.23558	face eyes black looked hair head white eye features fine brow dress almost pale round long full dark tall large
# 19	0.24686	thought enough look moment way eyes ever seemed another mine mind longer eye continued quiet doubt found turn spirit thus
#
# [beta: 0.03598]
# <600> LL/token: -9.59547
# <610> LL/token: -9.59232
# <620> LL/token: -9.58745
# <630> LL/token: -9.5902
# <640> LL/token: -9.58298
# <650> LL/token: -9.58358
# <660> LL/token: -9.58811
# <670> LL/token: -9.58266
# <680> LL/token: -9.57982
# <690> LL/token: -9.58176
#
# 0	0.21509	still heart cold blood strong rose lay fast thought broken near frame tears felt came feeling fell true left grew
# 1	0.24178	john wife rochester never name married house knew brother father husband fortune quite rivers mason england called sisters man either
# 2	0.2665	long come home till two three away leave mary get new ago morning take last stay sent diana way hour
# 3	0.23787	voice something without words sort hear question heard tone soon ear sound strange answer lips rochester spoke still nothing speak
# 4	0.27654	must shall sir know say n't tell think better make whether talk may let give come away take soon anything
# 5	0.20873	little years child girl first school poor old girls french children lowood age used young since men almost began english
# 6	0.22746	new best great least much thoughts even seemed never certain nature though present grace mind self become change always often
# 7	0.22633	half hour bessie minutes bread room night bed another helen tea water breakfast take told order thus nursery let adele
# 8	0.27141	door rochester room came went left open house night heard back step saw followed hall way opened towards shut turned
# 9	0.20127	thornfield house hall first saw passed away wild long half sought church look found though place post expected enough might
# 10	0.17078	sky trees wind moon dark bright sun night soft round rising high hill green blue wild cloud road sweet seemed
# 11	0.23456	miss mrs fairfax reed lady ingram eyre jane temple adele called taken sir rochester ladies master heard brocklehurst young eshton
# 12	0.23599	life might love well never thought felt world hope heart existence god knew live bear death good loved past strength
# 13	0.21313	power ever even man done character offer know life without either god pride nature felt taste spirit soon help enough
# 14	0.25635	room fire stood table sat chair near little head drawing hands side window bed glass round candle two light book
# 15	0.21131	every last made night word gave jane point seemed glance way many deep rochester days rather work instantly received close
# 16	0.20342	good pleasure thing sense got jane believe interest bad affection state natural wish general ought result real feelings reason part
# 17	0.21784	much though good ever heart nothing less made presence feel hard woman man still well sure handsome countenance expression smile
# 18	0.22334	face eyes black hair head white round quite looking full pale brow put looked well eye almost tall arm forehead
# 19	0.23558	eyes read thought make mind mine moment doubt look enough eye longer never another rather face seemed fear turn idea
#
# [beta: 0.03683]
# <700> LL/token: -9.59271
# <710> LL/token: -9.56838
# <720> LL/token: -9.57002
# <730> LL/token: -9.58142
# <740> LL/token: -9.57968
# <750> LL/token: -9.5776
# <760> LL/token: -9.58385
# <770> LL/token: -9.57845
# <780> LL/token: -9.56841
# <790> LL/token: -9.57776
#
